# %%
import pandas as pd
from pyspark.sql import SparkSession

# Criar sessão do Spark
spark = SparkSession.builder.appName("PySpark_Escola").getOrCreate()

# Criar dados para turmas
dados_turmas = pd.DataFrame({
    "id_turma": [1, 2, 3, 4],
    "nome_turma": ["Turma A", "Turma B", "Turma C", "Turma D"],
    "disciplina": ["Matemática", "História", "Física", "Química"],
    "ano": [2024, 2023, 2024, 2023],
    "num_alunos": [30, 25, 20, 28]
})

df_turmas = spark.createDataFrame(dados_turmas)
df_turmas.createOrReplaceTempView("turmas")

# Criar dados para alunos
dados_alunos = pd.DataFrame({
    "id_aluno": [1, 2, 3, 4, 5, 6],
    "nome": ["João Silva", "Maria Santos", "Carlos Nunes", "Ana Costa", "Rui Pereira", "Sara Mendes"],
    "turma": [1, 2, 3, 1, 2, 4],
    "idade": [16, 17, 15, 16, 18, 17],
    "desempenho": ["Bom", "Excelente", "Médio", "Bom", "Fraco", "Excelente"]
})

df_alunos = spark.createDataFrame(dados_alunos)
df_alunos.createOrReplaceTempView("alunos")

# Consultas SQL
print("1️⃣ Listar todas as turmas:")
spark.sql("SELECT * FROM turmas").show()

print("2️⃣ Listar apenas nome e disciplina das turmas:")
spark.sql("SELECT nome_turma, disciplina FROM turmas").show()

print("3️⃣ Filtrar turmas do ano de 2024:")
spark.sql("SELECT * FROM turmas WHERE ano = 2024").show()

print("4️⃣ Ordenar turmas por número de alunos (decrescente):")
spark.sql("SELECT * FROM turmas ORDER BY num_alunos DESC").show()

print("5️⃣ Contar quantas turmas existem:")
spark.sql("SELECT COUNT(*) AS total_turmas FROM turmas").show()

print("6️⃣ Listar todos os alunos:")
spark.sql("SELECT * FROM alunos").show()

print("7️⃣ Listar apenas nome e idade dos alunos:")
spark.sql("SELECT nome, idade FROM alunos").show()

print("8️⃣ Filtrar alunos com idade superior a 16 anos:")
spark.sql("SELECT * FROM alunos WHERE idade > 16").show()

print("9️⃣ Ordenar alunos por nome:")
spark.sql("SELECT * FROM alunos ORDER BY nome").show()

print("🔟 Contar quantos alunos existem:")
spark.sql("SELECT COUNT(*) AS total_alunos FROM alunos").show()

print("1️⃣1️⃣ Listar alunos com desempenho 'Excelente':")
spark.sql("SELECT * FROM alunos WHERE desempenho = 'Excelente'").show()

print("1️⃣2️⃣ Mostrar alunos da 'Turma A':")
spark.sql("SELECT * FROM alunos WHERE turma = 1").show()

print("1️⃣3️⃣ Calcular a idade média dos alunos:")
spark.sql("SELECT AVG(idade) AS idade_media FROM alunos").show()

print("1️⃣4️⃣ Contar quantos alunos existem por turma:")
spark.sql("SELECT turma, COUNT(*) AS total_alunos FROM alunos GROUP BY turma").show()

print("1️⃣5️⃣ Listar alunos com categoria de idade:")
spark.sql("""
    SELECT *, 
        CASE 
            WHEN idade <= 16 THEN 'Menor de idade' 
            ELSE 'Maior de idade' 
        END AS categoria_idade
    FROM alunos
""").show()

print("1️⃣6️⃣ Criar coluna 'aprovado' com base no desempenho:")
spark.sql("""
    SELECT *, 
        CASE 
            WHEN desempenho IN ('Bom', 'Excelente') THEN 'Sim' 
            ELSE 'Não' 
        END AS aprovado
    FROM alunos
""").show()

print("1️⃣7️⃣ Juntar dados de alunos e disciplinas via INNER JOIN:")
spark.sql("""
    SELECT a.nome, t.disciplina 
    FROM alunos a
    INNER JOIN turmas t ON a.turma = t.id_turma
""").show()

print("1️⃣8️⃣ Identificar turmas sem alunos:")
spark.sql("""
    SELECT * FROM turmas 
    WHERE id_turma NOT IN (SELECT DISTINCT turma FROM alunos)
""").show()

print("1️⃣9️⃣ Criar ranking das turmas com mais alunos:")
spark.sql("""
    SELECT *, 
        DENSE_RANK() OVER (ORDER BY num_alunos DESC) AS ranking 
    FROM turmas
""").show()

print("2️⃣0️⃣ Apresentar as duas turmas com mais alunos:")
spark.sql("""
    SELECT * FROM turmas 
    ORDER BY num_alunos DESC 
    LIMIT 2
""").show()

# Fechar sessão
spark.stop()
# Out:
# 1️⃣ Listar todas as turmas:
# +--------+----------+----------+----+----------+
# |id_turma|nome_turma|disciplina| ano|num_alunos|
# +--------+----------+----------+----+----------+
# |       1|   Turma A|Matemática|2024|        30|
# |       2|   Turma B|  História|2023|        25|
# |       3|   Turma C|    Física|2024|        20|
# |       4|   Turma D|   Química|2023|        28|
# +--------+----------+----------+----+----------+
#
# 2️⃣ Listar apenas nome e disciplina das turmas:
# +----------+----------+
# |nome_turma|disciplina|
# +----------+----------+
# |   Turma A|Matemática|
# |   Turma B|  História|
# |   Turma C|    Física|
# |   Turma D|   Química|
# +----------+----------+
#
# 3️⃣ Filtrar turmas do ano de 2024:
# +--------+----------+----------+----+----------+
# |id_turma|nome_turma|disciplina| ano|num_alunos|
# +--------+----------+----------+----+----------+
# |       1|   Turma A|Matemática|2024|        30|
# |       3|   Turma C|    Física|2024|        20|
# +--------+----------+----------+----+----------+
#
# 4️⃣ Ordenar turmas por número de alunos (decrescente):
# +--------+----------+----------+----+----------+
# |id_turma|nome_turma|disciplina| ano|num_alunos|
# +--------+----------+----------+----+----------+
# |       1|   Turma A|Matemática|2024|        30|
# |       4|   Turma D|   Química|2023|        28|
# |       2|   Turma B|  História|2023|        25|
# |       3|   Turma C|    Física|2024|        20|
# +--------+----------+----------+----+----------+
#
# 5️⃣ Contar quantas turmas existem:
# +------------+
# |total_turmas|
# +------------+
# |           4|
# +------------+
#
# 6️⃣ Listar todos os alunos:
# +--------+------------+-----+-----+----------+
# |id_aluno|        nome|turma|idade|desempenho|
# +--------+------------+-----+-----+----------+
# |       1|  João Silva|    1|   16|       Bom|
# |       2|Maria Santos|    2|   17| Excelente|
# |       3|Carlos Nunes|    3|   15|     Médio|
# |       4|   Ana Costa|    1|   16|       Bom|
# |       5| Rui Pereira|    2|   18|     Fraco|
# |       6| Sara Mendes|    4|   17| Excelente|
# +--------+------------+-----+-----+----------+
#
# 7️⃣ Listar apenas nome e idade dos alunos:
# +------------+-----+
# |        nome|idade|
# +------------+-----+
# |  João Silva|   16|
# |Maria Santos|   17|
# |Carlos Nunes|   15|
# |   Ana Costa|   16|
# | Rui Pereira|   18|
# | Sara Mendes|   17|
# +------------+-----+
#
# 8️⃣ Filtrar alunos com idade superior a 16 anos:
# +--------+------------+-----+-----+----------+
# |id_aluno|        nome|turma|idade|desempenho|
# +--------+------------+-----+-----+----------+
# |       2|Maria Santos|    2|   17| Excelente|
# |       5| Rui Pereira|    2|   18|     Fraco|
# |       6| Sara Mendes|    4|   17| Excelente|
# +--------+------------+-----+-----+----------+
#
# 9️⃣ Ordenar alunos por nome:
# +--------+------------+-----+-----+----------+
# |id_aluno|        nome|turma|idade|desempenho|
# +--------+------------+-----+-----+----------+
# |       4|   Ana Costa|    1|   16|       Bom|
# |       3|Carlos Nunes|    3|   15|     Médio|
# |       1|  João Silva|    1|   16|       Bom|
# |       2|Maria Santos|    2|   17| Excelente|
# |       5| Rui Pereira|    2|   18|     Fraco|
# |       6| Sara Mendes|    4|   17| Excelente|
# +--------+------------+-----+-----+----------+
#
# 🔟 Contar quantos alunos existem:
# +------------+
# |total_alunos|
# +------------+
# |           6|
# +------------+
#
# 1️⃣1️⃣ Listar alunos com desempenho 'Excelente':
# +--------+------------+-----+-----+----------+
# |id_aluno|        nome|turma|idade|desempenho|
# +--------+------------+-----+-----+----------+
# |       2|Maria Santos|    2|   17| Excelente|
# |       6| Sara Mendes|    4|   17| Excelente|
# +--------+------------+-----+-----+----------+
#
# 1️⃣2️⃣ Mostrar alunos da 'Turma A':
# +--------+----------+-----+-----+----------+
# |id_aluno|      nome|turma|idade|desempenho|
# +--------+----------+-----+-----+----------+
# |       1|João Silva|    1|   16|       Bom|
# |       4| Ana Costa|    1|   16|       Bom|
# +--------+----------+-----+-----+----------+
#
# 1️⃣3️⃣ Calcular a idade média dos alunos:
# +-----------+
# |idade_media|
# +-----------+
# |       16.5|
# +-----------+
#
# 1️⃣4️⃣ Contar quantos alunos existem por turma:
# +-----+------------+
# |turma|total_alunos|
# +-----+------------+
# |    1|           2|
# |    2|           2|
# |    3|           1|
# |    4|           1|
# +-----+------------+
#
# 1️⃣5️⃣ Listar alunos com categoria de idade:
# +--------+------------+-----+-----+----------+---------------+
# |id_aluno|        nome|turma|idade|desempenho|categoria_idade|
# +--------+------------+-----+-----+----------+---------------+
# |       1|  João Silva|    1|   16|       Bom| Menor de idade|
# |       2|Maria Santos|    2|   17| Excelente| Maior de idade|
# |       3|Carlos Nunes|    3|   15|     Médio| Menor de idade|
# |       4|   Ana Costa|    1|   16|       Bom| Menor de idade|
# |       5| Rui Pereira|    2|   18|     Fraco| Maior de idade|
# |       6| Sara Mendes|    4|   17| Excelente| Maior de idade|
# +--------+------------+-----+-----+----------+---------------+
#
# 1️⃣6️⃣ Criar coluna 'aprovado' com base no desempenho:
# +--------+------------+-----+-----+----------+--------+
# |id_aluno|        nome|turma|idade|desempenho|aprovado|
# +--------+------------+-----+-----+----------+--------+
# |       1|  João Silva|    1|   16|       Bom|     Sim|
# |       2|Maria Santos|    2|   17| Excelente|     Sim|
# |       3|Carlos Nunes|    3|   15|     Médio|     Não|
# |       4|   Ana Costa|    1|   16|       Bom|     Sim|
# |       5| Rui Pereira|    2|   18|     Fraco|     Não|
# |       6| Sara Mendes|    4|   17| Excelente|     Sim|
# +--------+------------+-----+-----+----------+--------+
#
# 1️⃣7️⃣ Juntar dados de alunos e disciplinas via INNER JOIN:
# +------------+----------+
# |        nome|disciplina|
# +------------+----------+
# |  João Silva|Matemática|
# |   Ana Costa|Matemática|
# |Maria Santos|  História|
# | Rui Pereira|  História|
# |Carlos Nunes|    Física|
# | Sara Mendes|   Química|
# +------------+----------+
#
# 1️⃣8️⃣ Identificar turmas sem alunos:
# +--------+----------+----------+---+----------+
# |id_turma|nome_turma|disciplina|ano|num_alunos|
# +--------+----------+----------+---+----------+
# +--------+----------+----------+---+----------+
#
# 1️⃣9️⃣ Criar ranking das turmas com mais alunos:
# +--------+----------+----------+----+----------+-------+
# |id_turma|nome_turma|disciplina| ano|num_alunos|ranking|
# +--------+----------+----------+----+----------+-------+
# |       1|   Turma A|Matemática|2024|        30|      1|
# |       4|   Turma D|   Química|2023|        28|      2|
# |       2|   Turma B|  História|2023|        25|      3|
# |       3|   Turma C|    Física|2024|        20|      4|
# +--------+----------+----------+----+----------+-------+
#
# 2️⃣0️⃣ Apresentar as duas turmas com mais alunos:
# +--------+----------+----------+----+----------+
# |id_turma|nome_turma|disciplina| ano|num_alunos|
# +--------+----------+----------+----+----------+
# |       1|   Turma A|Matemática|2024|        30|
# |       4|   Turma D|   Química|2023|        28|
# +--------+----------+----------+----+----------+
